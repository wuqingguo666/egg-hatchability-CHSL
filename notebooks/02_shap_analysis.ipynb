# %% [markdown]
# # Out-of-fold CHSL SHAP analysis
#
# Each outer fold trains a new CHSL model, including a CTGAN fitted only on minority observations from that training fold. SHAP then explains the held-out fold. The combined explanations therefore cover all observations without explaining in-sample predictions.

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
if project_root.name == 'notebooks':
    project_root = project_root.parent

# %% [markdown]
# The full model-agnostic analysis is computationally expensive. Run the cell below after completing the model evaluation environment setup.

# %%
subprocess.run(
    [sys.executable, str(project_root / 'scripts' / 'run_shap.py')],
    check=True,
)
